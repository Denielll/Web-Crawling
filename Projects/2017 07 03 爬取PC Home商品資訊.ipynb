# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
# 關掉Javascript，如果想要爬取的內容不見了，資訊很有可能藏在 Network-XHR裡的某個文件的 Request URL，是json格式。
# 如以下requests.get("url")

# %%
res = requests.get("http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=sony&page=1&sort=rnk/dc")

# 由於PC home是瀑布式的，要抓取下面的商品，要修改一下剛剛打的網址
# http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=sony&page=1&sort=rnk/dc
# http://ecshweb.pchome.com.tw/search/v3.3/all/results?q=sony&page=2&sort=rnk/dc    # 1變成2

# %%
res.json().keys()
# Out:
# dict_keys(['prods', 'token', 'QTime', 'q', 'subq', 'totalPage', 'range', 'cateName', 'totalRows'])

# %%
d = pd.DataFrame(res.json()["prods"])

# %%
d
# Out:
#                   Id author brand  cateId couponActid  \
# 0   DGBT1I-A90064873               DYAQA6          []
# 1   DYAD3N-A90080QZV               DYAD3N          []
# 2   DYAD37-A90080IHS               DYAD37          []
# 3   DCAIDH-A90084GL6               DCAIDH          []
# 4   DPAE03-A9007MIYA               DPAE03          []
# 5   DYAD0D-A90085BIO               DYAD0D          []
# 6   DGAD01-A90054RYV               DGAD81          []
# 7   DYAD21-A900860MV               DYAD21          []
# 8   DGAD81-A9007L7OQ               DGAD81          []
# 9   DYAD0D-A90084YX9               DYAD0D          []
# 10  DYAD21-A900881HX               DYAD21          []
# 11  DYAD3H-A90082HG3               DYAD3H          []
# 12  DYAD3I-A9007JH2P               DYAD3I          []
# 13  DGBQ1H-A9005VV2K               DGBQ1H          []
# 14  DPADOK-A9007CT0C               DPAD06          []
# 15  DGBJA7-A90088G9L               DGBJA7          []
# ...
